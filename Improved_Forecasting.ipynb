# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("train.csv", parse_dates=['date'])
df.set_index('date', inplace=True)

# %%
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df['dayofweek'] = df.index.dayofweek
df['is_weekend'] = df.index.dayofweek.isin([5, 6]).astype(int)

# %%
sales = df['sales']
sales.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# Sort and group
df = df.sort_values(['store_nbr', 'family'])

group_cols = ['store_nbr', 'family']
g = df.groupby(group_cols)['sales']


for d in [1, 7, 14, 28, 56]:
    df[f'lag_{d}'] = g.shift(d)


for w in ['7D', '14D']:
    name = f'rolling_{w[:-1]}_mean'
    df[name] = (
        g.apply(lambda s: s.shift(1).rolling(w).mean())
          .reset_index(level=group_cols, drop=True)
    )

# %% [markdown]
# # Explore the data of holidays.csv to see if we can get some useful features

# %%
holidays = pd.read_csv('holidays_events.csv', parse_dates=['date'])
holidays.set_index('date', inplace=True)

# %%
num_holidays = len(holidays['description'].unique())

# %% [markdown]
# # Let's merge df with holidays on the index col 'date'

# %%
df = (
    df
    .reset_index()
    .merge(
        holidays.reset_index(),
        on="date",
        how="left"
    )
    .set_index("date")
)

# %%
df['is_holiday'] = df['type'].notna().astype(int)

# %%
holiday_col = df.pop('is_holiday')
pos = df.columns.get_loc('rolling_14_mean')
df.insert(pos+1, 'is_holiday', holiday_col)

# %%
df['transferred'] = df['transferred'].fillna(0).astype(int)

# %%
cols = ['type','locale','locale_name','description']
df[cols] = df[cols].fillna('NO_HOLIDAY')

# %%
def encode_columns(df, columns, placeholder="NO_HOLIDAY"):
    for col in columns:
        mask = df[col] == placeholder

        le = LabelEncoder()
        le.fit(df.loc[~mask, col].astype(str))

        df.loc[~mask, col] = le.transform(df.loc[~mask, col].astype(str)) + 1

        df.loc[mask, col] = 0

        df[col] = df[col].astype(int)

    return df

# %%
cols = ['type','locale','locale_name','description']
df[cols] = df[cols].fillna('NO_HOLIDAY')

# %%
df = encode_columns(df, cols)

# %%
lag_rolling_cols = [
    'lag_1', 'lag_7', 'lag_14', 'lag_28', 'lag_56',
    'rolling_7_mean', 'rolling_14_mean'
]
df = df.dropna(subset=lag_rolling_cols)

# %%
df.head()
# Out:
#                 id  store_nbr      family  sales  onpromotion  year  month  \
# date
# 2013-02-26   99792          1  AUTOMOTIVE    0.0            0  2013      2
# 2013-02-27  101574          1  AUTOMOTIVE    2.0            0  2013      2
# 2013-02-28  103356          1  AUTOMOTIVE    1.0            0  2013      2
# 2013-03-01  105138          1  AUTOMOTIVE    2.0            0  2013      3
# 2013-03-02  106920          1  AUTOMOTIVE    1.0            0  2013      3
#
#             day  dayofweek  is_weekend  ...  lag_28  lag_56  rolling_7_mean  \
# date                                    ...
# 2013-02-26   26          1           0  ...     2.0     0.0        2.000000
# 2013-02-27   27          2           0  ...     6.0     2.0        1.428571
# 2013-02-28   28          3           0  ...     0.0     3.0        1.428571
# 2013-03-01    1          4           0  ...     3.0     3.0        1.428571
# 2013-03-02    2          5           1  ...     0.0     5.0        1.428571
#
#             rolling_14_mean  is_holiday  type  locale  locale_name  \
# date
# 2013-02-26         1.285714           0     0       0            0
# 2013-02-27         1.285714           0     0       0            0
# 2013-02-28         1.428571           0     0       0            0
# 2013-03-01         1.500000           0     0       0            0
# 2013-03-02         1.642857           1     4       1           16
#
#             description  transferred
# date
# 2013-02-26            0            0
# 2013-02-27            0            0
# 2013-02-28            0            0
# 2013-03-01            0            0
# 2013-03-02           26            0
#
# [5 rows x 23 columns]

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2013-02-26 00:00:00'), Timestamp('2017-08-15 00:00:00'))

# %%
cutoff_date = "2017-07-15"

# %%
train_df = df[df.index < cutoff_date]
val_df   = df[df.index >= cutoff_date]

# %%
X_train = train_df.drop(['sales', 'id', 'family'], axis=1)
y_train = train_df['sales']

# %%
X_val = val_df.drop(['sales', 'id', 'family'], axis=1)
y_val = val_df['sales']

# %%
from xgboost import XGBRegressor
model = XGBRegressor(
    n_estimators = 300,
    learning_rate = 0.1,
    max_depth = 7,
    reg_alpha = 0,
    reg_lambda = 0.5,
    subsample = 1.0,
    colsample_bytree = 0.8,
    random_state = 42,
    verbosity = 0,
    tree_method      = "gpu_hist"
)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_fit  = model.predict(X_train)
y_pred = model.predict(X_val)

# %%
mae = mean_absolute_error(y_train, y_fit)

print(f"Training MAE: {mae:.2f}")
# Out:
# Training MAE: 42.21

# %%
test_mae = mean_absolute_error(y_val, y_pred)
print(f"Test MAE: {test_mae:.2f}")
# Out:
# Test MAE: 58.52

# %%
model = XGBRegressor(
    n_estimators = 1000,
    learning_rate = 0.1,
    max_depth = 7,
    reg_alpha = 0,
    reg_lambda = 0.5,
    subsample = 1.0,
    colsample_bytree = 0.8,
    random_state = 42,
    verbosity = 0,
    tree_method = "gpu_hist",
    early_stopping_rounds = 50
)

# %%
model.fit(X_train, y_train,
          eval_set = [(X_train, y_train), (X_val, y_val)],
          verbose = True)
# Out:
# [0]	validation_0-rmse:1012.30674	validation_1-rmse:1165.41086
# [1]	validation_0-rmse:920.38407	validation_1-rmse:1050.71397
# [2]	validation_0-rmse:837.81884	validation_1-rmse:948.01217
# [3]	validation_0-rmse:764.39428	validation_1-rmse:856.72534
# [4]	validation_0-rmse:699.08870	validation_1-rmse:773.94158
# [5]	validation_0-rmse:640.95298	validation_1-rmse:700.61605
# [6]	validation_0-rmse:589.15200	validation_1-rmse:635.04381
# [7]	validation_0-rmse:543.28705	validation_1-rmse:576.67727
# [8]	validation_0-rmse:503.04616	validation_1-rmse:524.64360
# [9]	validation_0-rmse:466.62774	validation_1-rmse:479.18601
# [10]	validation_0-rmse:435.38239	validation_1-rmse:439.18990
# [11]	validation_0-rmse:407.96446	validation_1-rmse:404.40830
# [12]	validation_0-rmse:384.13033	validation_1-rmse:373.58354
# [13]	validation_0-rmse:363.51732	validation_1-rmse:347.24513
# [14]	validation_0-rmse:345.20772	validation_1-rmse:324.14894
# [15]	validation_0-rmse:329.88922	validation_1-rmse:305.01577
# [16]	validation_0-rmse:315.83372	validation_1-rmse:288.80405
# [17]	validation_0-rmse:303.77251	validation_1-rmse:275.20437
# [18]	validation_0-rmse:293.57124	validation_1-rmse:264.34925
# [19]	validation_0-rmse:285.06295	validation_1-rmse:254.79602
# [20]	validation_0-rmse:277.74463	validation_1-rmse:247.08690
# [21]	validation_0-rmse:270.86408	validation_1-rmse:241.09282
# [22]	validation_0-rmse:265.19094	validation_1-rmse:236.11560
# [23]	validation_0-rmse:260.32464	validation_1-rmse:232.43020
# [24]	validation_0-rmse:256.22364	validation_1-rmse:229.18564
# [25]	validation_0-rmse:251.69180	validation_1-rmse:226.61666
# [26]	validation_0-rmse:248.29256	validation_1-rmse:224.81897
# [27]	validation_0-rmse:245.81547	validation_1-rmse:223.55694
# [28]	validation_0-rmse:243.03590	validation_1-rmse:222.39752
# [29]	validation_0-rmse:240.71760	validation_1-rmse:221.56490
# [30]	validation_0-rmse:238.49241	validation_1-rmse:220.90955
# [31]	validation_0-rmse:236.52927	validation_1-rmse:220.54697
# [32]	validation_0-rmse:235.03830	validation_1-rmse:220.04299
# [33]	validation_0-rmse:233.28111	validation_1-rmse:219.70322
# [34]	validation_0-rmse:231.90882	validation_1-rmse:219.44282
# [35]	validation_0-rmse:230.27189	validation_1-rmse:219.01680
# [36]	validation_0-rmse:229.08620	validation_1-rmse:218.78437
# [37]	validation_0-rmse:227.56774	validation_1-rmse:218.64748
# [38]	validation_0-rmse:226.32710	validation_1-rmse:218.87516
# [39]	validation_0-rmse:225.49677	validation_1-rmse:219.19744
# [40]	validation_0-rmse:224.39511	validation_1-rmse:219.04524
# [41]	validation_0-rmse:223.48470	validation_1-rmse:218.67502
# [42]	validation_0-rmse:222.50538	validation_1-rmse:217.73730
# [43]	validation_0-rmse:221.92112	validation_1-rmse:217.84073
# [44]	validation_0-rmse:221.15509	validation_1-rmse:217.26630
# [45]	validation_0-rmse:220.42130	validation_1-rmse:217.61261
# [46]	validation_0-rmse:219.55238	validation_1-rmse:217.44278
# [47]	validation_0-rmse:218.57443	validation_1-rmse:217.33528
# [48]	validation_0-rmse:217.57207	validation_1-rmse:217.22648
# [49]	validation_0-rmse:216.82077	validation_1-rmse:217.21078
# [50]	validation_0-rmse:216.42253	validation_1-rmse:217.26539
# [51]	validation_0-rmse:215.84351	validation_1-rmse:216.99300
# [52]	validation_0-rmse:215.11696	validation_1-rmse:217.13818
# [53]	validation_0-rmse:214.00636	validation_1-rmse:217.16499
# [54]	validation_0-rmse:213.30908	validation_1-rmse:217.25662
# [55]	validation_0-rmse:212.72662	validation_1-rmse:217.01343
# [56]	validation_0-rmse:212.12267	validation_1-rmse:217.11333
# [57]	validation_0-rmse:211.66993	validation_1-rmse:216.94160
# [58]	validation_0-rmse:211.01177	validation_1-rmse:216.89558
# [59]	validation_0-rmse:210.64298	validation_1-rmse:216.98794
# [60]	validation_0-rmse:209.69278	validation_1-rmse:217.36358
# [61]	validation_0-rmse:209.40275	validation_1-rmse:217.35313
# [62]	validation_0-rmse:209.14315	validation_1-rmse:217.31772
# [63]	validation_0-rmse:208.76269	validation_1-rmse:217.19055
# [64]	validation_0-rmse:208.60798	validation_1-rmse:217.16951
# [65]	validation_0-rmse:208.41014	validation_1-rmse:217.16189
# [66]	validation_0-rmse:207.83932	validation_1-rmse:217.06367
# [67]	validation_0-rmse:207.37727	validation_1-rmse:216.93388
# [68]	validation_0-rmse:207.22516	validation_1-rmse:216.96382
# [69]	validation_0-rmse:207.10991	validation_1-rmse:216.82347
# [70]	validation_0-rmse:206.89317	validation_1-rmse:216.96075
# [71]	validation_0-rmse:206.76106	validation_1-rmse:217.06257
# [72]	validation_0-rmse:206.67814	validation_1-rmse:217.06019
# [73]	validation_0-rmse:206.16052	validation_1-rmse:217.17761
# [74]	validation_0-rmse:205.91380	validation_1-rmse:217.23105
# [75]	validation_0-rmse:205.23595	validation_1-rmse:216.66496
# [76]	validation_0-rmse:205.05222	validation_1-rmse:216.45902
# [77]	validation_0-rmse:204.84556	validation_1-rmse:215.39946
# [78]	validation_0-rmse:204.65584	validation_1-rmse:215.39693
# [79]	validation_0-rmse:204.59485	validation_1-rmse:215.32060
# [80]	validation_0-rmse:204.36149	validation_1-rmse:215.37836
# [81]	validation_0-rmse:203.60109	validation_1-rmse:215.39412
# [82]	validation_0-rmse:203.29052	validation_1-rmse:215.11043
# [83]	validation_0-rmse:203.03241	validation_1-rmse:215.39933
# [84]	validation_0-rmse:202.43401	validation_1-rmse:215.41819
# [85]	validation_0-rmse:202.09346	validation_1-rmse:215.30708
# [86]	validation_0-rmse:201.87130	validation_1-rmse:215.54076
# [87]	validation_0-rmse:201.58515	validation_1-rmse:213.80405
# [88]	validation_0-rmse:201.45573	validation_1-rmse:213.88761
# [89]	validation_0-rmse:200.98692	validation_1-rmse:213.72132
# [90]	validation_0-rmse:200.48927	validation_1-rmse:213.35796
# [91]	validation_0-rmse:200.39091	validation_1-rmse:213.30283
# [92]	validation_0-rmse:199.83995	validation_1-rmse:213.02668
# [93]	validation_0-rmse:199.33629	validation_1-rmse:213.06564
# [94]	validation_0-rmse:198.95036	validation_1-rmse:212.92120
# [95]	validation_0-rmse:198.45858	validation_1-rmse:212.95074
# [96]	validation_0-rmse:198.23018	validation_1-rmse:213.03733
# [97]	validation_0-rmse:197.47610	validation_1-rmse:212.76625
# [98]	validation_0-rmse:197.09763	validation_1-rmse:212.33679
# [99]	validation_0-rmse:196.73597	validation_1-rmse:212.34835
# [100]	validation_0-rmse:196.46030	validation_1-rmse:211.07905
# [101]	validation_0-rmse:196.19693	validation_1-rmse:211.05872
# [102]	validation_0-rmse:196.12983	validation_1-rmse:210.68191
# [103]	validation_0-rmse:195.60224	validation_1-rmse:210.49195
# [104]	validation_0-rmse:195.30807	validation_1-rmse:209.87248
# [105]	validation_0-rmse:194.87007	validation_1-rmse:210.25230
# [106]	validation_0-rmse:194.61121	validation_1-rmse:210.24035
# [107]	validation_0-rmse:194.49986	validation_1-rmse:210.23878
# [108]	validation_0-rmse:194.22385	validation_1-rmse:210.24631
# [109]	validation_0-rmse:193.96426	validation_1-rmse:210.14052
# [110]	validation_0-rmse:193.82843	validation_1-rmse:209.99518
# [111]	validation_0-rmse:193.61700	validation_1-rmse:209.99560
# [112]	validation_0-rmse:193.30087	validation_1-rmse:209.84478
# [113]	validation_0-rmse:193.15823	validation_1-rmse:209.76650
# [114]	validation_0-rmse:192.91534	validation_1-rmse:209.89835
# [115]	validation_0-rmse:192.81252	validation_1-rmse:209.86485
# [116]	validation_0-rmse:192.56399	validation_1-rmse:209.86863
# [117]	validation_0-rmse:192.15644	validation_1-rmse:209.86386
# [118]	validation_0-rmse:191.89764	validation_1-rmse:209.83181
# [119]	validation_0-rmse:191.78831	validation_1-rmse:209.91868
# [120]	validation_0-rmse:191.49969	validation_1-rmse:209.73216
# [121]	validation_0-rmse:191.21244	validation_1-rmse:209.71098
# [122]	validation_0-rmse:191.05447	validation_1-rmse:209.80758
# [123]	validation_0-rmse:190.85260	validation_1-rmse:210.14519
# [124]	validation_0-rmse:190.68413	validation_1-rmse:209.31782
# [125]	validation_0-rmse:190.41602	validation_1-rmse:209.28753
# [126]	validation_0-rmse:190.30935	validation_1-rmse:209.23806
# [127]	validation_0-rmse:189.74391	validation_1-rmse:209.31088
# [128]	validation_0-rmse:189.47033	validation_1-rmse:209.26392
# [129]	validation_0-rmse:189.33828	validation_1-rmse:209.05389
# [130]	validation_0-rmse:188.97202	validation_1-rmse:208.81043
# [131]	validation_0-rmse:188.81748	validation_1-rmse:208.68182
# [132]	validation_0-rmse:188.46998	validation_1-rmse:208.65138
# [133]	validation_0-rmse:188.26221	validation_1-rmse:208.34214
# [134]	validation_0-rmse:188.14299	validation_1-rmse:208.37594
# [135]	validation_0-rmse:187.82573	validation_1-rmse:208.21034
# [136]	validation_0-rmse:187.68555	validation_1-rmse:208.19102
# [137]	validation_0-rmse:187.55530	validation_1-rmse:208.18908
# [138]	validation_0-rmse:187.40909	validation_1-rmse:208.37967
# [139]	validation_0-rmse:187.06051	validation_1-rmse:208.24075
# [140]	validation_0-rmse:186.88912	validation_1-rmse:208.24841
# [141]	validation_0-rmse:186.73842	validation_1-rmse:208.21734
# [142]	validation_0-rmse:186.39907	validation_1-rmse:208.23010
# [143]	validation_0-rmse:186.20872	validation_1-rmse:208.10410
# [144]	validation_0-rmse:186.02436	validation_1-rmse:208.12704
# [145]	validation_0-rmse:185.89633	validation_1-rmse:208.11529
# [146]	validation_0-rmse:185.76244	validation_1-rmse:208.12324
# [147]	validation_0-rmse:185.63930	validation_1-rmse:208.05749
# [148]	validation_0-rmse:185.21974	validation_1-rmse:208.07985
# [149]	validation_0-rmse:185.17561	validation_1-rmse:208.07962
# [150]	validation_0-rmse:184.88126	validation_1-rmse:208.12112
# [151]	validation_0-rmse:184.68411	validation_1-rmse:208.28404
# [152]	validation_0-rmse:184.34108	validation_1-rmse:208.30232
# [153]	validation_0-rmse:184.17452	validation_1-rmse:208.07863
# [154]	validation_0-rmse:184.07683	validation_1-rmse:207.99590
# [155]	validation_0-rmse:184.00987	validation_1-rmse:207.97005
# [156]	validation_0-rmse:183.76691	validation_1-rmse:207.87977
# [157]	validation_0-rmse:183.59248	validation_1-rmse:207.84836
# [158]	validation_0-rmse:183.52015	validation_1-rmse:207.87057
# [159]	validation_0-rmse:183.23482	validation_1-rmse:207.84386
# [160]	validation_0-rmse:182.97619	validation_1-rmse:207.76684
# [161]	validation_0-rmse:182.67405	validation_1-rmse:207.90130
# [162]	validation_0-rmse:182.48482	validation_1-rmse:208.20917
# [163]	validation_0-rmse:182.02842	validation_1-rmse:208.68220
# [164]	validation_0-rmse:181.79727	validation_1-rmse:208.65277
# [165]	validation_0-rmse:181.55130	validation_1-rmse:208.67697
# [166]	validation_0-rmse:181.40064	validation_1-rmse:208.87945
# [167]	validation_0-rmse:181.21364	validation_1-rmse:208.82269
# [168]	validation_0-rmse:181.01485	validation_1-rmse:208.75306
# [169]	validation_0-rmse:180.84574	validation_1-rmse:208.77550
# [170]	validation_0-rmse:180.69709	validation_1-rmse:208.73059
# [171]	validation_0-rmse:180.66498	validation_1-rmse:208.67685
# [172]	validation_0-rmse:180.34248	validation_1-rmse:208.60367
# [173]	validation_0-rmse:180.20092	validation_1-rmse:208.23301
# [174]	validation_0-rmse:179.85739	validation_1-rmse:208.22718
# [175]	validation_0-rmse:179.71398	validation_1-rmse:208.19092
# [176]	validation_0-rmse:179.52128	validation_1-rmse:208.17004
# [177]	validation_0-rmse:179.45703	validation_1-rmse:208.11215
# [178]	validation_0-rmse:179.29890	validation_1-rmse:208.10750
# [179]	validation_0-rmse:179.22503	validation_1-rmse:208.09356
# [180]	validation_0-rmse:179.02940	validation_1-rmse:208.02589
# [181]	validation_0-rmse:178.91137	validation_1-rmse:207.85635
# [182]	validation_0-rmse:178.76671	validation_1-rmse:207.81592
# [183]	validation_0-rmse:178.67736	validation_1-rmse:207.83032
# [184]	validation_0-rmse:178.53653	validation_1-rmse:207.82300
# [185]	validation_0-rmse:178.31036	validation_1-rmse:207.78873
# [186]	validation_0-rmse:178.22456	validation_1-rmse:207.71257
# [187]	validation_0-rmse:177.97249	validation_1-rmse:207.66688
# [188]	validation_0-rmse:177.84051	validation_1-rmse:207.84496
# [189]	validation_0-rmse:177.75704	validation_1-rmse:207.83276
# [190]	validation_0-rmse:177.62707	validation_1-rmse:207.65318
# [191]	validation_0-rmse:177.45852	validation_1-rmse:207.59174
# [192]	validation_0-rmse:177.40361	validation_1-rmse:207.60185
# [193]	validation_0-rmse:177.20736	validation_1-rmse:207.51295
# [194]	validation_0-rmse:177.10411	validation_1-rmse:207.48437
# [195]	validation_0-rmse:176.94970	validation_1-rmse:207.58606
# [196]	validation_0-rmse:176.49363	validation_1-rmse:207.56473
# [197]	validation_0-rmse:176.31042	validation_1-rmse:207.57195
# [198]	validation_0-rmse:176.12304	validation_1-rmse:207.52236
# [199]	validation_0-rmse:175.97901	validation_1-rmse:207.52438
# [200]	validation_0-rmse:175.78665	validation_1-rmse:207.40898
# [201]	validation_0-rmse:175.72084	validation_1-rmse:207.46926
# [202]	validation_0-rmse:175.58697	validation_1-rmse:207.45538
# [203]	validation_0-rmse:175.46460	validation_1-rmse:207.39606
# [204]	validation_0-rmse:175.30728	validation_1-rmse:207.37031
# [205]	validation_0-rmse:174.99451	validation_1-rmse:207.42113
# [206]	validation_0-rmse:174.73860	validation_1-rmse:207.43426
# [207]	validation_0-rmse:174.63909	validation_1-rmse:207.39147
# [208]	validation_0-rmse:174.40780	validation_1-rmse:207.39192
# [209]	validation_0-rmse:174.20307	validation_1-rmse:207.39241
# [210]	validation_0-rmse:174.11982	validation_1-rmse:207.40272
# [211]	validation_0-rmse:173.97258	validation_1-rmse:207.41164
# [212]	validation_0-rmse:173.88036	validation_1-rmse:207.40232
# [213]	validation_0-rmse:173.77072	validation_1-rmse:207.38489
# [214]	validation_0-rmse:173.68013	validation_1-rmse:207.39904
# [215]	validation_0-rmse:173.42995	validation_1-rmse:207.13700
# [216]	validation_0-rmse:173.38433	validation_1-rmse:207.14434
# [217]	validation_0-rmse:173.28710	validation_1-rmse:207.14471
# [218]	validation_0-rmse:173.13984	validation_1-rmse:207.15999
# [219]	validation_0-rmse:172.90672	validation_1-rmse:207.12476
# [220]	validation_0-rmse:172.87827	validation_1-rmse:207.13292
# [221]	validation_0-rmse:172.70365	validation_1-rmse:207.21787
# [222]	validation_0-rmse:172.48843	validation_1-rmse:207.19927
# [223]	validation_0-rmse:172.39030	validation_1-rmse:207.19378
# [224]	validation_0-rmse:172.31188	validation_1-rmse:207.29212
# [225]	validation_0-rmse:172.28288	validation_1-rmse:207.26928
# [226]	validation_0-rmse:172.15252	validation_1-rmse:207.18773
# [227]	validation_0-rmse:172.05434	validation_1-rmse:207.23978
# [228]	validation_0-rmse:171.98334	validation_1-rmse:207.17568
# [229]	validation_0-rmse:171.87127	validation_1-rmse:207.17447
# [230]	validation_0-rmse:171.62805	validation_1-rmse:207.14695
# [231]	validation_0-rmse:171.46631	validation_1-rmse:207.07606
# [232]	validation_0-rmse:171.33241	validation_1-rmse:207.04940
# [233]	validation_0-rmse:171.25368	validation_1-rmse:207.05269
# [234]	validation_0-rmse:171.10868	validation_1-rmse:207.03753
# [235]	validation_0-rmse:170.99436	validation_1-rmse:206.99123
# [236]	validation_0-rmse:170.89527	validation_1-rmse:207.31124
# [237]	validation_0-rmse:170.74944	validation_1-rmse:207.22934
# [238]	validation_0-rmse:170.49461	validation_1-rmse:207.45842
# [239]	validation_0-rmse:170.38212	validation_1-rmse:207.50267
# [240]	validation_0-rmse:170.26761	validation_1-rmse:207.50605
# [241]	validation_0-rmse:170.15972	validation_1-rmse:207.46659
# [242]	validation_0-rmse:170.04693	validation_1-rmse:207.46458
# [243]	validation_0-rmse:169.94812	validation_1-rmse:207.51808
# [244]	validation_0-rmse:169.83647	validation_1-rmse:207.51516
# [245]	validation_0-rmse:169.66469	validation_1-rmse:207.50382
# [246]	validation_0-rmse:169.62673	validation_1-rmse:207.44973
# [247]	validation_0-rmse:169.53112	validation_1-rmse:207.49015
# [248]	validation_0-rmse:169.26706	validation_1-rmse:207.48100
# [249]	validation_0-rmse:169.18594	validation_1-rmse:207.47269
# [250]	validation_0-rmse:169.06307	validation_1-rmse:207.44179
# [251]	validation_0-rmse:168.94473	validation_1-rmse:207.39275
# [252]	validation_0-rmse:168.84488	validation_1-rmse:207.37214
# [253]	validation_0-rmse:168.67533	validation_1-rmse:207.54311
# [254]	validation_0-rmse:168.58761	validation_1-rmse:207.45773
# [255]	validation_0-rmse:168.41077	validation_1-rmse:207.41435
# [256]	validation_0-rmse:168.31473	validation_1-rmse:207.41460
# [257]	validation_0-rmse:168.19965	validation_1-rmse:207.36179
# [258]	validation_0-rmse:168.04862	validation_1-rmse:207.40865
# [259]	validation_0-rmse:167.92847	validation_1-rmse:207.38918
# [260]	validation_0-rmse:167.81368	validation_1-rmse:207.38825
# [261]	validation_0-rmse:167.63046	validation_1-rmse:207.38432
# [262]	validation_0-rmse:167.54330	validation_1-rmse:207.36356
# [263]	validation_0-rmse:167.50459	validation_1-rmse:207.36186
# [264]	validation_0-rmse:167.24955	validation_1-rmse:207.21254
# [265]	validation_0-rmse:167.15306	validation_1-rmse:207.12111
# [266]	validation_0-rmse:166.94017	validation_1-rmse:206.93083
# [267]	validation_0-rmse:166.89214	validation_1-rmse:207.12138
# [268]	validation_0-rmse:166.81940	validation_1-rmse:207.11333
# [269]	validation_0-rmse:166.73141	validation_1-rmse:207.10567
# [270]	validation_0-rmse:166.68266	validation_1-rmse:207.03200
# [271]	validation_0-rmse:166.59510	validation_1-rmse:207.04996
# [272]	validation_0-rmse:166.55113	validation_1-rmse:207.05040
# [273]	validation_0-rmse:166.46711	validation_1-rmse:207.03939
# [274]	validation_0-rmse:166.32298	validation_1-rmse:207.15231
# [275]	validation_0-rmse:166.15833	validation_1-rmse:207.02648
# [276]	validation_0-rmse:166.06013	validation_1-rmse:206.98197
# [277]	validation_0-rmse:165.97888	validation_1-rmse:206.97489
# [278]	validation_0-rmse:165.92751	validation_1-rmse:206.97428
# [279]	validation_0-rmse:165.82644	validation_1-rmse:206.97615
# [280]	validation_0-rmse:165.67911	validation_1-rmse:207.00948
# [281]	validation_0-rmse:165.56521	validation_1-rmse:207.01427
# [282]	validation_0-rmse:165.40658	validation_1-rmse:207.00211
# [283]	validation_0-rmse:165.29611	validation_1-rmse:207.02543
# [284]	validation_0-rmse:165.16804	validation_1-rmse:207.08147
# [285]	validation_0-rmse:165.10360	validation_1-rmse:207.08862
# [286]	validation_0-rmse:165.04099	validation_1-rmse:207.16891
# [287]	validation_0-rmse:164.95599	validation_1-rmse:207.10612
# [288]	validation_0-rmse:164.80888	validation_1-rmse:207.01773
# [289]	validation_0-rmse:164.76855	validation_1-rmse:206.97105
# [290]	validation_0-rmse:164.69861	validation_1-rmse:206.96573
# [291]	validation_0-rmse:164.60519	validation_1-rmse:206.91560
# [292]	validation_0-rmse:164.51177	validation_1-rmse:206.93903
# [293]	validation_0-rmse:164.37919	validation_1-rmse:206.95486
# [294]	validation_0-rmse:164.34454	validation_1-rmse:206.97420
# [295]	validation_0-rmse:164.23618	validation_1-rmse:206.62952
# [296]	validation_0-rmse:164.16937	validation_1-rmse:206.62970
# [297]	validation_0-rmse:164.10959	validation_1-rmse:206.62235
# [298]	validation_0-rmse:163.99588	validation_1-rmse:206.55558
# [299]	validation_0-rmse:163.84014	validation_1-rmse:206.74537
# [300]	validation_0-rmse:163.66680	validation_1-rmse:206.66404
# [301]	validation_0-rmse:163.61396	validation_1-rmse:206.71503
# [302]	validation_0-rmse:163.55351	validation_1-rmse:206.73429
# [303]	validation_0-rmse:163.37574	validation_1-rmse:206.72541
# [304]	validation_0-rmse:163.25993	validation_1-rmse:206.72596
# [305]	validation_0-rmse:163.22394	validation_1-rmse:206.73432
# [306]	validation_0-rmse:163.18196	validation_1-rmse:206.69849
# [307]	validation_0-rmse:163.12511	validation_1-rmse:206.82657
# [308]	validation_0-rmse:163.06481	validation_1-rmse:206.84533
# [309]	validation_0-rmse:162.99862	validation_1-rmse:206.83637
# [310]	validation_0-rmse:162.85357	validation_1-rmse:206.87849
# [311]	validation_0-rmse:162.73132	validation_1-rmse:206.86195
# [312]	validation_0-rmse:162.57095	validation_1-rmse:206.86882
# [313]	validation_0-rmse:162.38954	validation_1-rmse:206.91135
# [314]	validation_0-rmse:162.31127	validation_1-rmse:206.91575
# [315]	validation_0-rmse:162.22673	validation_1-rmse:206.94926
# [316]	validation_0-rmse:162.13409	validation_1-rmse:206.92776
# [317]	validation_0-rmse:162.06426	validation_1-rmse:206.90595
# [318]	validation_0-rmse:161.96614	validation_1-rmse:206.88840
# [319]	validation_0-rmse:161.78753	validation_1-rmse:206.85589
# [320]	validation_0-rmse:161.66432	validation_1-rmse:206.89557
# [321]	validation_0-rmse:161.61104	validation_1-rmse:206.82783
# [322]	validation_0-rmse:161.51367	validation_1-rmse:206.80180
# [323]	validation_0-rmse:161.43923	validation_1-rmse:206.79413
# [324]	validation_0-rmse:161.34669	validation_1-rmse:206.73108
# [325]	validation_0-rmse:161.21881	validation_1-rmse:206.69625
# [326]	validation_0-rmse:161.16603	validation_1-rmse:206.66871
# [327]	validation_0-rmse:161.07930	validation_1-rmse:206.70241
# [328]	validation_0-rmse:160.94357	validation_1-rmse:206.73839
# [329]	validation_0-rmse:160.89699	validation_1-rmse:206.73896
# [330]	validation_0-rmse:160.74510	validation_1-rmse:206.69576
# [331]	validation_0-rmse:160.69798	validation_1-rmse:206.74103
# [332]	validation_0-rmse:160.59655	validation_1-rmse:206.72781
# [333]	validation_0-rmse:160.51622	validation_1-rmse:206.73931
# [334]	validation_0-rmse:160.41849	validation_1-rmse:206.69322
# [335]	validation_0-rmse:160.35913	validation_1-rmse:206.73895
# [336]	validation_0-rmse:160.27563	validation_1-rmse:206.75160
# [337]	validation_0-rmse:160.11942	validation_1-rmse:206.72670
# [338]	validation_0-rmse:160.07628	validation_1-rmse:206.70465
# [339]	validation_0-rmse:160.05619	validation_1-rmse:206.69920
# [340]	validation_0-rmse:159.95395	validation_1-rmse:206.83093
# [341]	validation_0-rmse:159.80761	validation_1-rmse:206.81983
# [342]	validation_0-rmse:159.58361	validation_1-rmse:206.84645
# [343]	validation_0-rmse:159.56187	validation_1-rmse:206.83480
# [344]	validation_0-rmse:159.40512	validation_1-rmse:206.90904
# [345]	validation_0-rmse:159.34541	validation_1-rmse:206.88981
# [346]	validation_0-rmse:159.26833	validation_1-rmse:206.72800
# [347]	validation_0-rmse:159.13113	validation_1-rmse:206.71846
# [348]	validation_0-rmse:159.03498	validation_1-rmse:206.96569
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
from sklearn.metrics import mean_squared_log_error
rmsle = mean_squared_log_error(y_val, np.clip(y_pred, 0, None))
print(f"RMSLE: {rmsle:.4f}")
# Out:
# RMSLE: 0.2424

# %%
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
sns.histplot(y_train - y_fit, bins=30, kde=True)
plt.title("Training Residuals")
plt.xlabel("Error (Actual - Predicted)")


plt.subplot(1, 3, 2)
sns.histplot(y_val - y_pred, bins=30, kde=True, color='orange')
plt.title("Test Residuals")
plt.xlabel("Error (Actual - Predicted)")


plt.subplot(1, 3, 3)
plt.scatter(y_val, y_pred, alpha=0.1)
plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'r--')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.tight_layout()
plt.show()

# %%
plot_df = val_df.copy()
plot_df["predicted"] = y_pred
plot_df["actual"] = y_val

# Group by date and sum to collapse across all store/family combos
daily = plot_df.groupby("date")[["actual", "predicted"]].sum()

# Plot
plt.figure(figsize=(14,5))
plt.plot(daily.index, daily["actual"], label="Actual", linewidth=2)
plt.plot(daily.index, daily["predicted"], label="Predicted", linestyle="--")
plt.title("Total Sales per Day (Actual vs Predicted)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
