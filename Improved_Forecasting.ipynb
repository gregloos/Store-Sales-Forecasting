# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("train.csv", parse_dates=['date'])
df.set_index('date', inplace=True)

# %%
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df['dayofweek'] = df.index.dayofweek
df['is_weekend'] = df.index.dayofweek.isin([5, 6]).astype(int)

# %%
sales = df['sales']
sales.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# Sort and group
df = df.sort_values(['store_nbr', 'family'])

group_cols = ['store_nbr', 'family']
g = df.groupby(group_cols)['sales']


for d in [1, 7, 14, 28, 56]:
    df[f'lag_{d}'] = g.shift(d)


for w in ['7D', '14D']:
    name = f'rolling_{w[:-1]}_mean'
    df[name] = (
        g.apply(lambda s: s.shift(1).rolling(w).mean())
          .reset_index(level=group_cols, drop=True)
    )

# %% [markdown]
# # Explore the data of holidays.csv to see if we can get some useful features

# %%
holidays = pd.read_csv('holidays_events.csv', parse_dates=['date'])
holidays.set_index('date', inplace=True)

# %%
num_holidays = len(holidays['description'].unique())

# %% [markdown]
# # Let's merge df with holidays on the index col 'date'

# %%
df = (
    df
    .reset_index()
    .merge(
        holidays.reset_index(),
        on="date",
        how="left"
    )
    .set_index("date")
)

# %%
df['is_holiday'] = df['type'].notna().astype(int)

# %%
holiday_col = df.pop('is_holiday')
pos = df.columns.get_loc('rolling_14_mean')
df.insert(pos+1, 'is_holiday', holiday_col)

# %%
df['transferred'] = df['transferred'].fillna(0).astype(int)

# %%
cols = ['type','locale','locale_name','description']
df[cols] = df[cols].fillna('NO_HOLIDAY')

# %%
def encode_columns(df, columns, placeholder="NO_HOLIDAY"):
    for col in columns:
        mask = df[col] == placeholder

        le = LabelEncoder()
        le.fit(df.loc[~mask, col].astype(str))

        df.loc[~mask, col] = le.transform(df.loc[~mask, col].astype(str)) + 1

        df.loc[mask, col] = 0

        df[col] = df[col].astype(int)

    return df

# %%
cols = ['type','locale','locale_name','description']
df[cols] = df[cols].fillna('NO_HOLIDAY')

# %%
df = encode_columns(df, cols)

# %%
lag_rolling_cols = [
    'lag_1', 'lag_7', 'lag_14', 'lag_28', 'lag_56',
    'rolling_7_mean', 'rolling_14_mean'
]
df = df.dropna(subset=lag_rolling_cols)

# %%
df.head()
# Out:
#                 id  store_nbr      family  sales  onpromotion  year  month  \
# date
# 2013-02-26   99792          1  AUTOMOTIVE    0.0            0  2013      2
# 2013-02-27  101574          1  AUTOMOTIVE    2.0            0  2013      2
# 2013-02-28  103356          1  AUTOMOTIVE    1.0            0  2013      2
# 2013-03-01  105138          1  AUTOMOTIVE    2.0            0  2013      3
# 2013-03-02  106920          1  AUTOMOTIVE    1.0            0  2013      3
#
#             day  dayofweek  is_weekend  ...  lag_28  lag_56  rolling_7_mean  \
# date                                    ...
# 2013-02-26   26          1           0  ...     2.0     0.0        2.000000
# 2013-02-27   27          2           0  ...     6.0     2.0        1.428571
# 2013-02-28   28          3           0  ...     0.0     3.0        1.428571
# 2013-03-01    1          4           0  ...     3.0     3.0        1.428571
# 2013-03-02    2          5           1  ...     0.0     5.0        1.428571
#
#             rolling_14_mean  is_holiday  type  locale  locale_name  \
# date
# 2013-02-26         1.285714           0     0       0            0
# 2013-02-27         1.285714           0     0       0            0
# 2013-02-28         1.428571           0     0       0            0
# 2013-03-01         1.500000           0     0       0            0
# 2013-03-02         1.642857           1     4       1           16
#
#             description  transferred
# date
# 2013-02-26            0            0
# 2013-02-27            0            0
# 2013-02-28            0            0
# 2013-03-01            0            0
# 2013-03-02           26            0
#
# [5 rows x 23 columns]

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2013-02-26 00:00:00'), Timestamp('2017-08-15 00:00:00'))

# %%
cutoff_date = "2017-07-15"

# %%
train_df = df[df.index < cutoff_date]
val_df   = df[df.index >= cutoff_date]

# %%
X_train = train_df.drop(['sales', 'id', 'family'], axis=1)
y_train = train_df['sales']

# %%
X_val = val_df.drop(['sales', 'id', 'family'], axis=1)
y_val = val_df['sales']

# %%
from xgboost import XGBRegressor
model = XGBRegressor(
    n_estimators = 300,
    learning_rate = 0.1,
    max_depth = 7,
    reg_alpha = 0,
    reg_lambda = 0.5,
    subsample = 1.0,
    colsample_bytree = 0.8,
    random_state = 42,
    verbosity = 0,
    tree_method      = "gpu_hist"
)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_fit  = model.predict(X_train)
y_pred = model.predict(X_val)

# %%
mae = mean_absolute_error(y_train, y_fit)

print(f"Training MAE: {mae:.2f}")
# Out:
# Training MAE: 42.21

# %%
test_mae = mean_absolute_error(y_val, y_pred)
print(f"Test MAE: {test_mae:.2f}")
# Out:
# Test MAE: 58.49

# %%
model = XGBRegressor(
    n_estimators = 1000,
    learning_rate = 0.1,
    max_depth = 7,
    reg_alpha = 0,
    reg_lambda = 0.5,
    subsample = 1.0,
    colsample_bytree = 0.8,
    random_state = 42,
    verbosity = 0,
    tree_method = "gpu_hist",
    early_stopping_rounds = 50
)

# %%
model.fit(X_train, y_train,
          eval_set = [(X_train, y_train), (X_val, y_val)],
          verbose = True)
# Out:
# [0]	validation_0-rmse:1012.30674	validation_1-rmse:1165.41086
# [1]	validation_0-rmse:920.38407	validation_1-rmse:1050.71397
# [2]	validation_0-rmse:837.81884	validation_1-rmse:948.01217
# [3]	validation_0-rmse:764.39429	validation_1-rmse:856.72534
# [4]	validation_0-rmse:699.08870	validation_1-rmse:773.94158
# [5]	validation_0-rmse:640.95298	validation_1-rmse:700.61605
# [6]	validation_0-rmse:589.15200	validation_1-rmse:635.04381
# [7]	validation_0-rmse:543.28706	validation_1-rmse:576.67727
# [8]	validation_0-rmse:503.04617	validation_1-rmse:524.64361
# [9]	validation_0-rmse:466.62775	validation_1-rmse:479.18602
# [10]	validation_0-rmse:435.38240	validation_1-rmse:439.18990
# [11]	validation_0-rmse:407.96447	validation_1-rmse:404.40831
# [12]	validation_0-rmse:384.13034	validation_1-rmse:373.58354
# [13]	validation_0-rmse:363.51733	validation_1-rmse:347.24513
# [14]	validation_0-rmse:345.20773	validation_1-rmse:324.14894
# [15]	validation_0-rmse:329.88923	validation_1-rmse:305.01577
# [16]	validation_0-rmse:315.83372	validation_1-rmse:288.80405
# [17]	validation_0-rmse:303.77252	validation_1-rmse:275.20437
# [18]	validation_0-rmse:293.57125	validation_1-rmse:264.34925
# [19]	validation_0-rmse:285.06296	validation_1-rmse:254.79602
# [20]	validation_0-rmse:277.74464	validation_1-rmse:247.08690
# [21]	validation_0-rmse:270.86409	validation_1-rmse:241.09282
# [22]	validation_0-rmse:265.19095	validation_1-rmse:236.11560
# [23]	validation_0-rmse:260.32465	validation_1-rmse:232.43020
# [24]	validation_0-rmse:256.22365	validation_1-rmse:229.18564
# [25]	validation_0-rmse:251.69181	validation_1-rmse:226.61666
# [26]	validation_0-rmse:248.29257	validation_1-rmse:224.81897
# [27]	validation_0-rmse:245.81548	validation_1-rmse:223.55694
# [28]	validation_0-rmse:243.03590	validation_1-rmse:222.39751
# [29]	validation_0-rmse:240.71760	validation_1-rmse:221.56490
# [30]	validation_0-rmse:238.49241	validation_1-rmse:220.90955
# [31]	validation_0-rmse:236.52927	validation_1-rmse:220.54697
# [32]	validation_0-rmse:235.03830	validation_1-rmse:220.04299
# [33]	validation_0-rmse:233.28111	validation_1-rmse:219.70322
# [34]	validation_0-rmse:231.90882	validation_1-rmse:219.44282
# [35]	validation_0-rmse:230.27190	validation_1-rmse:219.01680
# [36]	validation_0-rmse:229.08620	validation_1-rmse:218.78437
# [37]	validation_0-rmse:227.56774	validation_1-rmse:218.64747
# [38]	validation_0-rmse:226.32710	validation_1-rmse:218.87516
# [39]	validation_0-rmse:225.49677	validation_1-rmse:219.19744
# [40]	validation_0-rmse:224.39510	validation_1-rmse:219.04523
# [41]	validation_0-rmse:223.48469	validation_1-rmse:218.67502
# [42]	validation_0-rmse:222.50538	validation_1-rmse:217.73729
# [43]	validation_0-rmse:221.92112	validation_1-rmse:217.84073
# [44]	validation_0-rmse:221.15509	validation_1-rmse:217.26629
# [45]	validation_0-rmse:220.42130	validation_1-rmse:217.61261
# [46]	validation_0-rmse:219.55238	validation_1-rmse:217.44277
# [47]	validation_0-rmse:218.57443	validation_1-rmse:217.33527
# [48]	validation_0-rmse:217.57207	validation_1-rmse:217.22648
# [49]	validation_0-rmse:216.82077	validation_1-rmse:217.21077
# [50]	validation_0-rmse:216.42252	validation_1-rmse:217.26538
# [51]	validation_0-rmse:215.84351	validation_1-rmse:216.99299
# [52]	validation_0-rmse:215.11696	validation_1-rmse:217.13818
# [53]	validation_0-rmse:214.00636	validation_1-rmse:217.16499
# [54]	validation_0-rmse:213.30908	validation_1-rmse:217.25661
# [55]	validation_0-rmse:212.72662	validation_1-rmse:217.01343
# [56]	validation_0-rmse:212.12267	validation_1-rmse:217.11333
# [57]	validation_0-rmse:211.66993	validation_1-rmse:216.94160
# [58]	validation_0-rmse:211.01176	validation_1-rmse:216.89558
# [59]	validation_0-rmse:210.64298	validation_1-rmse:216.98794
# [60]	validation_0-rmse:209.69278	validation_1-rmse:217.36357
# [61]	validation_0-rmse:209.40275	validation_1-rmse:217.35312
# [62]	validation_0-rmse:209.14315	validation_1-rmse:217.31772
# [63]	validation_0-rmse:208.76269	validation_1-rmse:217.19055
# [64]	validation_0-rmse:208.60797	validation_1-rmse:217.16951
# [65]	validation_0-rmse:208.41014	validation_1-rmse:217.16188
# [66]	validation_0-rmse:207.83932	validation_1-rmse:217.06366
# [67]	validation_0-rmse:207.37727	validation_1-rmse:216.93387
# [68]	validation_0-rmse:207.22516	validation_1-rmse:216.96381
# [69]	validation_0-rmse:207.10991	validation_1-rmse:216.82347
# [70]	validation_0-rmse:206.89317	validation_1-rmse:216.96074
# [71]	validation_0-rmse:206.76106	validation_1-rmse:217.06257
# [72]	validation_0-rmse:206.67814	validation_1-rmse:217.06019
# [73]	validation_0-rmse:206.16052	validation_1-rmse:217.17761
# [74]	validation_0-rmse:205.91379	validation_1-rmse:217.23104
# [75]	validation_0-rmse:205.23595	validation_1-rmse:216.66496
# [76]	validation_0-rmse:205.05222	validation_1-rmse:216.45902
# [77]	validation_0-rmse:204.84556	validation_1-rmse:215.39946
# [78]	validation_0-rmse:204.65584	validation_1-rmse:215.39693
# [79]	validation_0-rmse:204.59485	validation_1-rmse:215.32060
# [80]	validation_0-rmse:204.36149	validation_1-rmse:215.37836
# [81]	validation_0-rmse:203.60109	validation_1-rmse:215.39411
# [82]	validation_0-rmse:203.29052	validation_1-rmse:215.11042
# [83]	validation_0-rmse:203.03241	validation_1-rmse:215.39933
# [84]	validation_0-rmse:202.43401	validation_1-rmse:215.41819
# [85]	validation_0-rmse:202.09346	validation_1-rmse:215.30708
# [86]	validation_0-rmse:201.87129	validation_1-rmse:215.54075
# [87]	validation_0-rmse:201.58514	validation_1-rmse:213.80405
# [88]	validation_0-rmse:201.45572	validation_1-rmse:213.88761
# [89]	validation_0-rmse:200.98691	validation_1-rmse:213.72131
# [90]	validation_0-rmse:200.48926	validation_1-rmse:213.35796
# [91]	validation_0-rmse:200.39090	validation_1-rmse:213.30283
# [92]	validation_0-rmse:199.83995	validation_1-rmse:213.02667
# [93]	validation_0-rmse:199.33629	validation_1-rmse:213.06563
# [94]	validation_0-rmse:198.95036	validation_1-rmse:212.92119
# [95]	validation_0-rmse:198.45858	validation_1-rmse:212.95074
# [96]	validation_0-rmse:198.23017	validation_1-rmse:213.03733
# [97]	validation_0-rmse:197.47609	validation_1-rmse:212.76625
# [98]	validation_0-rmse:197.09761	validation_1-rmse:212.33678
# [99]	validation_0-rmse:196.73596	validation_1-rmse:212.34835
# [100]	validation_0-rmse:196.46028	validation_1-rmse:211.07904
# [101]	validation_0-rmse:196.19692	validation_1-rmse:211.05871
# [102]	validation_0-rmse:196.12982	validation_1-rmse:210.68191
# [103]	validation_0-rmse:195.60223	validation_1-rmse:210.49194
# [104]	validation_0-rmse:195.30805	validation_1-rmse:209.87248
# [105]	validation_0-rmse:194.87006	validation_1-rmse:210.25229
# [106]	validation_0-rmse:194.61119	validation_1-rmse:210.24035
# [107]	validation_0-rmse:194.49985	validation_1-rmse:210.23877
# [108]	validation_0-rmse:194.22384	validation_1-rmse:210.24631
# [109]	validation_0-rmse:193.96425	validation_1-rmse:210.14052
# [110]	validation_0-rmse:193.82842	validation_1-rmse:209.99518
# [111]	validation_0-rmse:193.61699	validation_1-rmse:209.99560
# [112]	validation_0-rmse:193.30086	validation_1-rmse:209.84478
# [113]	validation_0-rmse:193.15822	validation_1-rmse:209.76650
# [114]	validation_0-rmse:192.91533	validation_1-rmse:209.89834
# [115]	validation_0-rmse:192.81251	validation_1-rmse:209.86484
# [116]	validation_0-rmse:192.56399	validation_1-rmse:209.86863
# [117]	validation_0-rmse:192.15643	validation_1-rmse:209.86386
# [118]	validation_0-rmse:191.89763	validation_1-rmse:209.83181
# [119]	validation_0-rmse:191.78830	validation_1-rmse:209.91868
# [120]	validation_0-rmse:191.49968	validation_1-rmse:209.73216
# [121]	validation_0-rmse:191.21243	validation_1-rmse:209.71098
# [122]	validation_0-rmse:191.05446	validation_1-rmse:209.80758
# [123]	validation_0-rmse:190.85259	validation_1-rmse:210.14519
# [124]	validation_0-rmse:190.68412	validation_1-rmse:209.31782
# [125]	validation_0-rmse:190.41601	validation_1-rmse:209.28753
# [126]	validation_0-rmse:190.30934	validation_1-rmse:209.23806
# [127]	validation_0-rmse:189.74391	validation_1-rmse:209.31088
# [128]	validation_0-rmse:189.47033	validation_1-rmse:209.26392
# [129]	validation_0-rmse:189.33827	validation_1-rmse:209.05389
# [130]	validation_0-rmse:188.97201	validation_1-rmse:208.81043
# [131]	validation_0-rmse:188.81748	validation_1-rmse:208.68182
# [132]	validation_0-rmse:188.46997	validation_1-rmse:208.65138
# [133]	validation_0-rmse:188.26220	validation_1-rmse:208.34213
# [134]	validation_0-rmse:188.14299	validation_1-rmse:208.37594
# [135]	validation_0-rmse:187.82572	validation_1-rmse:208.21033
# [136]	validation_0-rmse:187.68554	validation_1-rmse:208.19102
# [137]	validation_0-rmse:187.55529	validation_1-rmse:208.18908
# [138]	validation_0-rmse:187.40908	validation_1-rmse:208.37967
# [139]	validation_0-rmse:187.06050	validation_1-rmse:208.24075
# [140]	validation_0-rmse:186.88911	validation_1-rmse:208.24841
# [141]	validation_0-rmse:186.73841	validation_1-rmse:208.21733
# [142]	validation_0-rmse:186.39906	validation_1-rmse:208.23010
# [143]	validation_0-rmse:186.20872	validation_1-rmse:208.10409
# [144]	validation_0-rmse:186.02435	validation_1-rmse:208.12704
# [145]	validation_0-rmse:185.89632	validation_1-rmse:208.11528
# [146]	validation_0-rmse:185.76243	validation_1-rmse:208.12324
# [147]	validation_0-rmse:185.63929	validation_1-rmse:208.05748
# [148]	validation_0-rmse:185.21974	validation_1-rmse:208.07985
# [149]	validation_0-rmse:185.17561	validation_1-rmse:208.07961
# [150]	validation_0-rmse:184.88126	validation_1-rmse:208.12112
# [151]	validation_0-rmse:184.68411	validation_1-rmse:208.28404
# [152]	validation_0-rmse:184.34107	validation_1-rmse:208.30231
# [153]	validation_0-rmse:184.17451	validation_1-rmse:208.07863
# [154]	validation_0-rmse:184.07682	validation_1-rmse:207.99590
# [155]	validation_0-rmse:184.00986	validation_1-rmse:207.97004
# [156]	validation_0-rmse:183.76690	validation_1-rmse:207.87976
# [157]	validation_0-rmse:183.59248	validation_1-rmse:207.84835
# [158]	validation_0-rmse:183.52014	validation_1-rmse:207.87057
# [159]	validation_0-rmse:183.23481	validation_1-rmse:207.84386
# [160]	validation_0-rmse:182.97618	validation_1-rmse:207.76683
# [161]	validation_0-rmse:182.67404	validation_1-rmse:207.90129
# [162]	validation_0-rmse:182.48481	validation_1-rmse:208.20916
# [163]	validation_0-rmse:182.02842	validation_1-rmse:208.68220
# [164]	validation_0-rmse:181.79726	validation_1-rmse:208.65277
# [165]	validation_0-rmse:181.55129	validation_1-rmse:208.67696
# [166]	validation_0-rmse:181.40064	validation_1-rmse:208.87945
# [167]	validation_0-rmse:181.21363	validation_1-rmse:208.82268
# [168]	validation_0-rmse:181.01484	validation_1-rmse:208.75306
# [169]	validation_0-rmse:180.84574	validation_1-rmse:208.77549
# [170]	validation_0-rmse:180.69708	validation_1-rmse:208.73058
# [171]	validation_0-rmse:180.66497	validation_1-rmse:208.67685
# [172]	validation_0-rmse:180.34247	validation_1-rmse:208.60366
# [173]	validation_0-rmse:180.20091	validation_1-rmse:208.23301
# [174]	validation_0-rmse:179.85738	validation_1-rmse:208.22717
# [175]	validation_0-rmse:179.71397	validation_1-rmse:208.19092
# [176]	validation_0-rmse:179.52127	validation_1-rmse:208.17004
# [177]	validation_0-rmse:179.45702	validation_1-rmse:208.11214
# [178]	validation_0-rmse:179.29889	validation_1-rmse:208.10749
# [179]	validation_0-rmse:179.22502	validation_1-rmse:208.09356
# [180]	validation_0-rmse:179.02939	validation_1-rmse:208.02588
# [181]	validation_0-rmse:178.91136	validation_1-rmse:207.85634
# [182]	validation_0-rmse:178.76671	validation_1-rmse:207.81592
# [183]	validation_0-rmse:178.67735	validation_1-rmse:207.83031
# [184]	validation_0-rmse:178.53653	validation_1-rmse:207.82299
# [185]	validation_0-rmse:178.31035	validation_1-rmse:207.78873
# [186]	validation_0-rmse:178.22455	validation_1-rmse:207.71256
# [187]	validation_0-rmse:177.97248	validation_1-rmse:207.66687
# [188]	validation_0-rmse:177.84050	validation_1-rmse:207.84495
# [189]	validation_0-rmse:177.75704	validation_1-rmse:207.83275
# [190]	validation_0-rmse:177.62706	validation_1-rmse:207.65317
# [191]	validation_0-rmse:177.45851	validation_1-rmse:207.59173
# [192]	validation_0-rmse:177.40360	validation_1-rmse:207.60184
# [193]	validation_0-rmse:177.20735	validation_1-rmse:207.51294
# [194]	validation_0-rmse:177.10410	validation_1-rmse:207.48436
# [195]	validation_0-rmse:176.94969	validation_1-rmse:207.58605
# [196]	validation_0-rmse:176.49363	validation_1-rmse:207.56473
# [197]	validation_0-rmse:176.31041	validation_1-rmse:207.57194
# [198]	validation_0-rmse:176.12304	validation_1-rmse:207.52236
# [199]	validation_0-rmse:175.97900	validation_1-rmse:207.52437
# [200]	validation_0-rmse:175.78664	validation_1-rmse:207.40897
# [201]	validation_0-rmse:175.72083	validation_1-rmse:207.46925
# [202]	validation_0-rmse:175.58696	validation_1-rmse:207.45537
# [203]	validation_0-rmse:175.46459	validation_1-rmse:207.39605
# [204]	validation_0-rmse:175.30727	validation_1-rmse:207.37031
# [205]	validation_0-rmse:174.99451	validation_1-rmse:207.42113
# [206]	validation_0-rmse:174.73859	validation_1-rmse:207.43425
# [207]	validation_0-rmse:174.63908	validation_1-rmse:207.39146
# [208]	validation_0-rmse:174.40779	validation_1-rmse:207.39192
# [209]	validation_0-rmse:174.20306	validation_1-rmse:207.39240
# [210]	validation_0-rmse:174.11982	validation_1-rmse:207.40271
# [211]	validation_0-rmse:173.97257	validation_1-rmse:207.41164
# [212]	validation_0-rmse:173.88035	validation_1-rmse:207.40232
# [213]	validation_0-rmse:173.77072	validation_1-rmse:207.38488
# [214]	validation_0-rmse:173.68012	validation_1-rmse:207.39903
# [215]	validation_0-rmse:173.42994	validation_1-rmse:207.13699
# [216]	validation_0-rmse:173.38433	validation_1-rmse:207.14433
# [217]	validation_0-rmse:173.28709	validation_1-rmse:207.14470
# [218]	validation_0-rmse:173.13983	validation_1-rmse:207.15998
# [219]	validation_0-rmse:172.90671	validation_1-rmse:207.12475
# [220]	validation_0-rmse:172.87826	validation_1-rmse:207.13292
# [221]	validation_0-rmse:172.70364	validation_1-rmse:207.21787
# [222]	validation_0-rmse:172.48842	validation_1-rmse:207.19927
# [223]	validation_0-rmse:172.39029	validation_1-rmse:207.19378
# [224]	validation_0-rmse:172.31187	validation_1-rmse:207.29211
# [225]	validation_0-rmse:172.28288	validation_1-rmse:207.26927
# [226]	validation_0-rmse:172.15251	validation_1-rmse:207.18773
# [227]	validation_0-rmse:172.05433	validation_1-rmse:207.23977
# [228]	validation_0-rmse:171.98333	validation_1-rmse:207.17567
# [229]	validation_0-rmse:171.87126	validation_1-rmse:207.17447
# [230]	validation_0-rmse:171.62804	validation_1-rmse:207.14694
# [231]	validation_0-rmse:171.46630	validation_1-rmse:207.07606
# [232]	validation_0-rmse:171.33240	validation_1-rmse:207.04939
# [233]	validation_0-rmse:171.25367	validation_1-rmse:207.05268
# [234]	validation_0-rmse:171.10867	validation_1-rmse:207.03752
# [235]	validation_0-rmse:170.99435	validation_1-rmse:206.99123
# [236]	validation_0-rmse:170.89526	validation_1-rmse:207.31123
# [237]	validation_0-rmse:170.74943	validation_1-rmse:207.22934
# [238]	validation_0-rmse:170.49460	validation_1-rmse:207.45841
# [239]	validation_0-rmse:170.38211	validation_1-rmse:207.50266
# [240]	validation_0-rmse:170.26760	validation_1-rmse:207.50605
# [241]	validation_0-rmse:170.15971	validation_1-rmse:207.46659
# [242]	validation_0-rmse:170.04692	validation_1-rmse:207.46458
# [243]	validation_0-rmse:169.94811	validation_1-rmse:207.51808
# [244]	validation_0-rmse:169.83646	validation_1-rmse:207.51516
# [245]	validation_0-rmse:169.66468	validation_1-rmse:207.50381
# [246]	validation_0-rmse:169.60671	validation_1-rmse:207.48999
# [247]	validation_0-rmse:169.45251	validation_1-rmse:207.47384
# [248]	validation_0-rmse:169.21864	validation_1-rmse:207.45860
# [249]	validation_0-rmse:168.94544	validation_1-rmse:207.45418
# [250]	validation_0-rmse:168.60252	validation_1-rmse:207.40866
# [251]	validation_0-rmse:168.43371	validation_1-rmse:207.36714
# [252]	validation_0-rmse:168.38720	validation_1-rmse:207.31813
# [253]	validation_0-rmse:168.32098	validation_1-rmse:207.39358
# [254]	validation_0-rmse:168.20256	validation_1-rmse:207.31206
# [255]	validation_0-rmse:168.04829	validation_1-rmse:207.33133
# [256]	validation_0-rmse:167.92311	validation_1-rmse:207.34479
# [257]	validation_0-rmse:167.82465	validation_1-rmse:207.32724
# [258]	validation_0-rmse:167.63941	validation_1-rmse:207.34212
# [259]	validation_0-rmse:167.51272	validation_1-rmse:207.34670
# [260]	validation_0-rmse:167.42476	validation_1-rmse:207.32064
# [261]	validation_0-rmse:167.32022	validation_1-rmse:207.25856
# [262]	validation_0-rmse:167.19550	validation_1-rmse:207.21087
# [263]	validation_0-rmse:167.12212	validation_1-rmse:207.31360
# [264]	validation_0-rmse:167.03769	validation_1-rmse:207.30351
# [265]	validation_0-rmse:166.91240	validation_1-rmse:207.20746
# [266]	validation_0-rmse:166.81273	validation_1-rmse:207.18870
# [267]	validation_0-rmse:166.73731	validation_1-rmse:207.09899
# [268]	validation_0-rmse:166.61156	validation_1-rmse:207.15605
# [269]	validation_0-rmse:166.55958	validation_1-rmse:207.14529
# [270]	validation_0-rmse:166.31853	validation_1-rmse:207.15296
# [271]	validation_0-rmse:166.25561	validation_1-rmse:207.14829
# [272]	validation_0-rmse:166.17510	validation_1-rmse:207.17161
# [273]	validation_0-rmse:166.07331	validation_1-rmse:207.06235
# [274]	validation_0-rmse:165.90472	validation_1-rmse:206.90083
# [275]	validation_0-rmse:165.82205	validation_1-rmse:206.62485
# [276]	validation_0-rmse:165.68897	validation_1-rmse:206.60109
# [277]	validation_0-rmse:165.60712	validation_1-rmse:206.45268
# [278]	validation_0-rmse:165.45811	validation_1-rmse:206.44141
# [279]	validation_0-rmse:165.38952	validation_1-rmse:206.50352
# [280]	validation_0-rmse:165.23763	validation_1-rmse:206.54797
# [281]	validation_0-rmse:165.04865	validation_1-rmse:206.64380
# [282]	validation_0-rmse:164.97504	validation_1-rmse:206.61786
# [283]	validation_0-rmse:164.85445	validation_1-rmse:206.53158
# [284]	validation_0-rmse:164.74502	validation_1-rmse:206.51173
# [285]	validation_0-rmse:164.63755	validation_1-rmse:206.52973
# [286]	validation_0-rmse:164.51369	validation_1-rmse:206.56418
# [287]	validation_0-rmse:164.49158	validation_1-rmse:206.54436
# [288]	validation_0-rmse:164.42469	validation_1-rmse:206.56315
# [289]	validation_0-rmse:164.29644	validation_1-rmse:206.62590
# [290]	validation_0-rmse:164.17383	validation_1-rmse:206.64727
# [291]	validation_0-rmse:164.02498	validation_1-rmse:206.62394
# [292]	validation_0-rmse:163.92807	validation_1-rmse:206.65749
# [293]	validation_0-rmse:163.84929	validation_1-rmse:206.69147
# [294]	validation_0-rmse:163.76921	validation_1-rmse:206.65521
# [295]	validation_0-rmse:163.71900	validation_1-rmse:206.71682
# [296]	validation_0-rmse:163.52819	validation_1-rmse:206.65378
# [297]	validation_0-rmse:163.49488	validation_1-rmse:206.62725
# [298]	validation_0-rmse:163.42289	validation_1-rmse:206.66175
# [299]	validation_0-rmse:163.05522	validation_1-rmse:206.63480
# [300]	validation_0-rmse:163.00539	validation_1-rmse:206.65293
# [301]	validation_0-rmse:162.92412	validation_1-rmse:206.61867
# [302]	validation_0-rmse:162.80657	validation_1-rmse:206.54379
# [303]	validation_0-rmse:162.77358	validation_1-rmse:206.47125
# [304]	validation_0-rmse:162.64787	validation_1-rmse:206.53806
# [305]	validation_0-rmse:162.50599	validation_1-rmse:206.35117
# [306]	validation_0-rmse:162.46207	validation_1-rmse:206.36992
# [307]	validation_0-rmse:162.40434	validation_1-rmse:206.43819
# [308]	validation_0-rmse:162.34238	validation_1-rmse:206.46446
# [309]	validation_0-rmse:162.29541	validation_1-rmse:206.50441
# [310]	validation_0-rmse:162.19071	validation_1-rmse:206.52671
# [311]	validation_0-rmse:162.14550	validation_1-rmse:206.31434
# [312]	validation_0-rmse:162.11539	validation_1-rmse:206.31113
# [313]	validation_0-rmse:161.94335	validation_1-rmse:206.39531
# [314]	validation_0-rmse:161.82827	validation_1-rmse:206.33122
# [315]	validation_0-rmse:161.78846	validation_1-rmse:206.34873
# [316]	validation_0-rmse:161.58810	validation_1-rmse:206.30975
# [317]	validation_0-rmse:161.49950	validation_1-rmse:206.28490
# [318]	validation_0-rmse:161.34904	validation_1-rmse:206.22472
# [319]	validation_0-rmse:161.21978	validation_1-rmse:206.13952
# [320]	validation_0-rmse:161.11104	validation_1-rmse:206.18672
# [321]	validation_0-rmse:161.03505	validation_1-rmse:206.21301
# [322]	validation_0-rmse:160.92631	validation_1-rmse:206.17359
# [323]	validation_0-rmse:160.78014	validation_1-rmse:206.14110
# [324]	validation_0-rmse:160.71260	validation_1-rmse:206.13728
# [325]	validation_0-rmse:160.59527	validation_1-rmse:206.16411
# [326]	validation_0-rmse:160.57060	validation_1-rmse:206.15603
# [327]	validation_0-rmse:160.47667	validation_1-rmse:206.11699
# [328]	validation_0-rmse:160.30243	validation_1-rmse:206.10533
# [329]	validation_0-rmse:160.21511	validation_1-rmse:206.08783
# [330]	validation_0-rmse:160.12253	validation_1-rmse:206.03822
# [331]	validation_0-rmse:160.01921	validation_1-rmse:206.02945
# [332]	validation_0-rmse:159.91555	validation_1-rmse:205.98228
# [333]	validation_0-rmse:159.82242	validation_1-rmse:205.95909
# [334]	validation_0-rmse:159.74283	validation_1-rmse:205.91188
# [335]	validation_0-rmse:159.68747	validation_1-rmse:205.93259
# [336]	validation_0-rmse:159.64304	validation_1-rmse:205.91744
# [337]	validation_0-rmse:159.57197	validation_1-rmse:205.91021
# [338]	validation_0-rmse:159.45541	validation_1-rmse:205.92228
# [339]	validation_0-rmse:159.39703	validation_1-rmse:205.88603
# [340]	validation_0-rmse:159.27196	validation_1-rmse:205.87229
# [341]	validation_0-rmse:159.18664	validation_1-rmse:205.85209
# [342]	validation_0-rmse:159.11290	validation_1-rmse:205.87983
# [343]	validation_0-rmse:159.08015	validation_1-rmse:205.84880
# [344]	validation_0-rmse:158.84684	validation_1-rmse:205.73848
# [345]	validation_0-rmse:158.76798	validation_1-rmse:205.70950
# [346]	validation_0-rmse:158.61977	validation_1-rmse:205.69032
# [347]	validation_0-rmse:158.58957	validation_1-rmse:205.67538
# [348]	validation_0-rmse:158.46789	validation_1-rmse:205.71741
# [349]	validation_0-rmse:158.28938	validation_1-rmse:205.63986
# [350]	validation_0-rmse:158.18998	validation_1-rmse:205.58833
# [351]	validation_0-rmse:158.10532	validation_1-rmse:205.59741
# [352]	validation_0-rmse:158.06829	validation_1-rmse:205.58432
# [353]	validation_0-rmse:157.97111	validation_1-rmse:205.57891
# [354]	validation_0-rmse:157.92269	validation_1-rmse:205.54960
# [355]	validation_0-rmse:157.76300	validation_1-rmse:205.52235
# [356]	validation_0-rmse:157.68372	validation_1-rmse:205.49451
# [357]	validation_0-rmse:157.56147	validation_1-rmse:205.40697
# [358]	validation_0-rmse:157.48017	validation_1-rmse:205.40406
# [359]	validation_0-rmse:157.42408	validation_1-rmse:205.41362
# [360]	validation_0-rmse:157.32983	validation_1-rmse:205.40957
# [361]	validation_0-rmse:157.20166	validation_1-rmse:205.47831
# [362]	validation_0-rmse:157.18014	validation_1-rmse:205.48119
# [363]	validation_0-rmse:157.14842	validation_1-rmse:205.46422
# [364]	validation_0-rmse:157.02345	validation_1-rmse:205.57398
# [365]	validation_0-rmse:156.84666	validation_1-rmse:205.52466
# [366]	validation_0-rmse:156.76656	validation_1-rmse:205.48280
# [367]	validation_0-rmse:156.69304	validation_1-rmse:205.43167
# [368]	validation_0-rmse:156.57613	validation_1-rmse:205.37887
# [369]	validation_0-rmse:156.47638	validation_1-rmse:205.35778
# [370]	validation_0-rmse:156.36198	validation_1-rmse:204.84701
# [371]	validation_0-rmse:156.30666	validation_1-rmse:204.83953
# [372]	validation_0-rmse:156.25558	validation_1-rmse:204.74113
# [373]	validation_0-rmse:156.18247	validation_1-rmse:204.77149
# [374]	validation_0-rmse:156.11745	validation_1-rmse:204.75920
# [375]	validation_0-rmse:156.03921	validation_1-rmse:204.69869
# [376]	validation_0-rmse:155.93198	validation_1-rmse:204.63240
# [377]	validation_0-rmse:155.88163	validation_1-rmse:204.61402
# [378]	validation_0-rmse:155.74524	validation_1-rmse:204.59600
# [379]	validation_0-rmse:155.65261	validation_1-rmse:204.59543
# [380]	validation_0-rmse:155.57803	validation_1-rmse:204.61753
# [381]	validation_0-rmse:155.50885	validation_1-rmse:204.62289
# [382]	validation_0-rmse:155.38489	validation_1-rmse:204.61261
# [383]	validation_0-rmse:155.31073	validation_1-rmse:204.59202
# [384]	validation_0-rmse:155.26809	validation_1-rmse:204.63682
# [385]	validation_0-rmse:155.15876	validation_1-rmse:204.81919
# [386]	validation_0-rmse:155.07626	validation_1-rmse:204.84900
# [387]	validation_0-rmse:154.89167	validation_1-rmse:204.83304
# [388]	validation_0-rmse:154.81225	validation_1-rmse:204.82024
# [389]	validation_0-rmse:154.71154	validation_1-rmse:204.79541
# [390]	validation_0-rmse:154.59515	validation_1-rmse:204.82501
# [391]	validation_0-rmse:154.54569	validation_1-rmse:204.82399
# [392]	validation_0-rmse:154.51392	validation_1-rmse:204.85377
# [393]	validation_0-rmse:154.46979	validation_1-rmse:204.84859
# [394]	validation_0-rmse:154.33197	validation_1-rmse:204.83031
# [395]	validation_0-rmse:154.29347	validation_1-rmse:204.82987
# [396]	validation_0-rmse:154.20501	validation_1-rmse:204.81856
# [397]	validation_0-rmse:154.12826	validation_1-rmse:204.79345
# [398]	validation_0-rmse:153.98149	validation_1-rmse:204.69955
# [399]	validation_0-rmse:153.95429	validation_1-rmse:204.66748
# [400]	validation_0-rmse:153.91656	validation_1-rmse:204.66671
# [401]	validation_0-rmse:153.82745	validation_1-rmse:204.66830
# [402]	validation_0-rmse:153.72712	validation_1-rmse:204.54906
# [403]	validation_0-rmse:153.68668	validation_1-rmse:204.55268
# [404]	validation_0-rmse:153.62328	validation_1-rmse:204.56130
# [405]	validation_0-rmse:153.52016	validation_1-rmse:204.55149
# [406]	validation_0-rmse:153.39617	validation_1-rmse:204.53777
# [407]	validation_0-rmse:153.33474	validation_1-rmse:204.51459
# [408]	validation_0-rmse:153.29590	validation_1-rmse:204.53629
# [409]	validation_0-rmse:153.26533	validation_1-rmse:204.54761
# [410]	validation_0-rmse:153.24116	validation_1-rmse:204.53282
# [411]	validation_0-rmse:153.20411	validation_1-rmse:204.45053
# [412]	validation_0-rmse:153.13472	validation_1-rmse:204.42565
# [413]	validation_0-rmse:153.04900	validation_1-rmse:204.45431
# [414]	validation_0-rmse:152.95421	validation_1-rmse:204.45748
# [415]	validation_0-rmse:152.81034	validation_1-rmse:204.42947
# [416]	validation_0-rmse:152.65450	validation_1-rmse:204.34864
# [417]	validation_0-rmse:152.59751	validation_1-rmse:204.44898
# [418]	validation_0-rmse:152.55603	validation_1-rmse:204.44788
# [419]	validation_0-rmse:152.49502	validation_1-rmse:204.40108
# [420]	validation_0-rmse:152.43246	validation_1-rmse:204.39384
# [421]	validation_0-rmse:152.37091	validation_1-rmse:204.37138
# [422]	validation_0-rmse:152.31060	validation_1-rmse:204.39239
# [423]	validation_0-rmse:152.26258	validation_1-rmse:204.40735
# [424]	validation_0-rmse:152.22017	validation_1-rmse:204.43364
# [425]	validation_0-rmse:152.18744	validation_1-rmse:204.45805
# [426]	validation_0-rmse:152.15455	validation_1-rmse:204.44085
# [427]	validation_0-rmse:152.12970	validation_1-rmse:204.45446
# [428]	validation_0-rmse:151.95070	validation_1-rmse:204.46657
# [429]	validation_0-rmse:151.72686	validation_1-rmse:204.47707
# [430]	validation_0-rmse:151.63061	validation_1-rmse:204.56841
# [431]	validation_0-rmse:151.59322	validation_1-rmse:204.55773
# [432]	validation_0-rmse:151.51907	validation_1-rmse:204.58259
# [433]	validation_0-rmse:151.46835	validation_1-rmse:204.57783
# [434]	validation_0-rmse:151.37737	validation_1-rmse:204.30965
# [435]	validation_0-rmse:151.29234	validation_1-rmse:204.33141
# [436]	validation_0-rmse:151.15303	validation_1-rmse:204.42193
# [437]	validation_0-rmse:151.07858	validation_1-rmse:204.42374
# [438]	validation_0-rmse:151.00374	validation_1-rmse:204.49762
# [439]	validation_0-rmse:150.97000	validation_1-rmse:204.51402
# [440]	validation_0-rmse:150.90035	validation_1-rmse:204.49384
# [441]	validation_0-rmse:150.83606	validation_1-rmse:204.48632
# [442]	validation_0-rmse:150.78695	validation_1-rmse:204.48616
# [443]	validation_0-rmse:150.67580	validation_1-rmse:204.52716
# [444]	validation_0-rmse:150.63750	validation_1-rmse:204.52404
# [445]	validation_0-rmse:150.61178	validation_1-rmse:204.54184
# [446]	validation_0-rmse:150.46324	validation_1-rmse:204.54393
# [447]	validation_0-rmse:150.41823	validation_1-rmse:204.54730
# [448]	validation_0-rmse:150.32138	validation_1-rmse:204.56378
# [449]	validation_0-rmse:150.24006	validation_1-rmse:204.54524
# [450]	validation_0-rmse:150.15257	validation_1-rmse:204.51510
# [451]	validation_0-rmse:150.08540	validation_1-rmse:204.52968
# [452]	validation_0-rmse:149.97662	validation_1-rmse:204.47500
# [453]	validation_0-rmse:149.87702	validation_1-rmse:204.45647
# [454]	validation_0-rmse:149.80391	validation_1-rmse:204.36150
# [455]	validation_0-rmse:149.58776	validation_1-rmse:204.36301
# [456]	validation_0-rmse:149.53910	validation_1-rmse:204.33045
# [457]	validation_0-rmse:149.50355	validation_1-rmse:204.37030
# [458]	validation_0-rmse:149.48842	validation_1-rmse:204.36076
# [459]	validation_0-rmse:149.43335	validation_1-rmse:204.35814
# [460]	validation_0-rmse:149.36004	validation_1-rmse:204.32786
# [461]	validation_0-rmse:149.29069	validation_1-rmse:204.31511
# [462]	validation_0-rmse:149.24233	validation_1-rmse:204.28602
# [463]	validation_0-rmse:149.17999	validation_1-rmse:204.27590
# [464]	validation_0-rmse:149.15747	validation_1-rmse:204.26970
# [465]	validation_0-rmse:149.12364	validation_1-rmse:204.26533
# [466]	validation_0-rmse:149.07021	validation_1-rmse:204.22811
# [467]	validation_0-rmse:148.95946	validation_1-rmse:204.22212
# [468]	validation_0-rmse:148.85301	validation_1-rmse:204.12276
# [469]	validation_0-rmse:148.83436	validation_1-rmse:204.12382
# [470]	validation_0-rmse:148.79240	validation_1-rmse:204.08180
# [471]	validation_0-rmse:148.73864	validation_1-rmse:204.06097
# [472]	validation_0-rmse:148.64782	validation_1-rmse:204.02895
# [473]	validation_0-rmse:148.55063	validation_1-rmse:204.01935
# [474]	validation_0-rmse:148.50921	validation_1-rmse:203.99882
# [475]	validation_0-rmse:148.47759	validation_1-rmse:203.98286
# [476]	validation_0-rmse:148.40421	validation_1-rmse:204.00979
# [477]	validation_0-rmse:148.36383	validation_1-rmse:204.01498
# [478]	validation_0-rmse:148.29948	validation_1-rmse:203.92120
# [479]	validation_0-rmse:148.16149	validation_1-rmse:203.94795
# [480]	validation_0-rmse:148.06239	validation_1-rmse:203.93321
# [481]	validation_0-rmse:148.04060	validation_1-rmse:203.92007
# [482]	validation_0-rmse:147.95469	validation_1-rmse:203.87852
# [483]	validation_0-rmse:147.90194	validation_1-rmse:203.90770
# [484]	validation_0-rmse:147.86300	validation_1-rmse:203.89135
# [485]	validation_0-rmse:147.82880	validation_1-rmse:203.90600
# [486]	validation_0-rmse:147.78777	validation_1-rmse:203.88008
# [487]	validation_0-rmse:147.76067	validation_1-rmse:203.90687
# [488]	validation_0-rmse:147.73828	validation_1-rmse:203.90796
# [489]	validation_0-rmse:147.65178	validation_1-rmse:203.90783
# [490]	validation_0-rmse:147.57381	validation_1-rmse:203.92599
# [491]	validation_0-rmse:147.48297	validation_1-rmse:203.87453
# [492]	validation_0-rmse:147.44159	validation_1-rmse:203.88124
# [493]	validation_0-rmse:147.38650	validation_1-rmse:203.92257
# [494]	validation_0-rmse:147.37432	validation_1-rmse:203.93863
# [495]	validation_0-rmse:147.34151	validation_1-rmse:203.97526
# [496]	validation_0-rmse:147.27585	validation_1-rmse:203.87112
# [497]	validation_0-rmse:147.23109	validation_1-rmse:203.89491
# [498]	validation_0-rmse:147.13750	validation_1-rmse:203.87149
# [499]	validation_0-rmse:147.09933	validation_1-rmse:203.89788
# [500]	validation_0-rmse:147.04909	validation_1-rmse:203.85990
# [501]	validation_0-rmse:146.98662	validation_1-rmse:203.81335
# [502]	validation_0-rmse:146.95770	validation_1-rmse:203.84614
# [503]	validation_0-rmse:146.89730	validation_1-rmse:203.85098
# [504]	validation_0-rmse:146.84017	validation_1-rmse:203.79585
# [505]	validation_0-rmse:146.76462	validation_1-rmse:203.82568
# [506]	validation_0-rmse:146.72841	validation_1-rmse:203.87906
# [507]	validation_0-rmse:146.65431	validation_1-rmse:203.83912
# [508]	validation_0-rmse:146.61576	validation_1-rmse:203.81314
# [509]	validation_0-rmse:146.57511	validation_1-rmse:203.79264
# [510]	validation_0-rmse:146.51722	validation_1-rmse:203.77197
# [511]	validation_0-rmse:146.45361	validation_1-rmse:203.75739
# [512]	validation_0-rmse:146.41617	validation_1-rmse:203.74236
# [513]	validation_0-rmse:146.38537	validation_1-rmse:203.72718
# [514]	validation_0-rmse:146.35044	validation_1-rmse:203.69669
# [515]	validation_0-rmse:146.31551	validation_1-rmse:203.66000
# [516]	validation_0-rmse:146.27407	validation_1-rmse:203.72633
# [517]	validation_0-rmse:146.12086	validation_1-rmse:203.71108
# [518]	validation_0-rmse:146.03426	validation_1-rmse:203.56696
# [519]	validation_0-rmse:145.96441	validation_1-rmse:203.57067
# [520]	validation_0-rmse:145.91204	validation_1-rmse:203.53830
# [521]	validation_0-rmse:145.84816	validation_1-rmse:203.55327
# [522]	validation_0-rmse:145.81310	validation_1-rmse:203.57067
# [523]	validation_0-rmse:145.76700	validation_1-rmse:203.56616
# [524]	validation_0-rmse:145.73947	validation_1-rmse:203.60224
# [525]	validation_0-rmse:145.70657	validation_1-rmse:203.62981
# [526]	validation_0-rmse:145.51194	validation_1-rmse:203.67156
# [527]	validation_0-rmse:145.45028	validation_1-rmse:203.56851
# [528]	validation_0-rmse:145.41509	validation_1-rmse:203.56792
# [529]	validation_0-rmse:145.38260	validation_1-rmse:203.56488
# [530]	validation_0-rmse:145.26049	validation_1-rmse:203.63502
# [531]	validation_0-rmse:145.23951	validation_1-rmse:203.58840
# [532]	validation_0-rmse:145.22436	validation_1-rmse:203.57728
# [533]	validation_0-rmse:145.17854	validation_1-rmse:203.57227
# [534]	validation_0-rmse:145.11982	validation_1-rmse:203.55449
# [535]	validation_0-rmse:145.08252	validation_1-rmse:203.55112
# [536]	validation_0-rmse:145.02284	validation_1-rmse:203.56120
# [537]	validation_0-rmse:144.94072	validation_1-rmse:203.51475
# [538]	validation_0-rmse:144.89038	validation_1-rmse:203.46533
# [539]	validation_0-rmse:144.83297	validation_1-rmse:203.43725
# [540]	validation_0-rmse:144.78021	validation_1-rmse:203.39461
# [541]	validation_0-rmse:144.71389	validation_1-rmse:203.38401
# [542]	validation_0-rmse:144.68026	validation_1-rmse:203.37128
# [543]	validation_0-rmse:144.64957	validation_1-rmse:203.34837
# [544]	validation_0-rmse:144.60342	validation_1-rmse:203.33869
# [545]	validation_0-rmse:144.55880	validation_1-rmse:203.36695
# [546]	validation_0-rmse:144.54075	validation_1-rmse:203.32644
# [547]	validation_0-rmse:144.49099	validation_1-rmse:203.32204
# [548]	validation_0-rmse:144.42727	validation_1-rmse:203.32303
# [549]	validation_0-rmse:144.36421	validation_1-rmse:203.33553
# [550]	validation_0-rmse:144.32234	validation_1-rmse:203.33716
# [551]	validation_0-rmse:144.28830	validation_1-rmse:203.34350
# [552]	validation_0-rmse:144.23500	validation_1-rmse:203.31670
# [553]	validation_0-rmse:144.21284	validation_1-rmse:203.31861
# [554]	validation_0-rmse:144.16238	validation_1-rmse:203.28203
# [555]	validation_0-rmse:144.12141	validation_1-rmse:203.26596
# [556]	validation_0-rmse:144.07753	validation_1-rmse:203.24452
# [557]	validation_0-rmse:143.84640	validation_1-rmse:203.20607
# [558]	validation_0-rmse:143.79305	validation_1-rmse:203.19480
# [559]	validation_0-rmse:143.71916	validation_1-rmse:203.19827
# [560]	validation_0-rmse:143.67852	validation_1-rmse:203.18023
# [561]	validation_0-rmse:143.60852	validation_1-rmse:203.12071
# [562]	validation_0-rmse:143.57094	validation_1-rmse:203.10923
# [563]	validation_0-rmse:143.51364	validation_1-rmse:203.07195
# [564]	validation_0-rmse:143.44384	validation_1-rmse:203.12980
# [565]	validation_0-rmse:143.38822	validation_1-rmse:203.21960
# [566]	validation_0-rmse:143.32005	validation_1-rmse:203.24918
# [567]	validation_0-rmse:143.27587	validation_1-rmse:203.24026
# [568]	validation_0-rmse:143.19589	validation_1-rmse:203.32338
# [569]	validation_0-rmse:143.14806	validation_1-rmse:203.56379
# [570]	validation_0-rmse:143.09792	validation_1-rmse:203.56501
# [571]	validation_0-rmse:143.02879	validation_1-rmse:203.69223
# [572]	validation_0-rmse:142.93090	validation_1-rmse:203.68026
# [573]	validation_0-rmse:142.85739	validation_1-rmse:203.68706
# [574]	validation_0-rmse:142.80326	validation_1-rmse:203.66849
# [575]	validation_0-rmse:142.56174	validation_1-rmse:203.66773
# [576]	validation_0-rmse:142.51029	validation_1-rmse:203.59436
# [577]	validation_0-rmse:142.44044	validation_1-rmse:203.75637
# [578]	validation_0-rmse:142.39365	validation_1-rmse:203.72546
# [579]	validation_0-rmse:142.31093	validation_1-rmse:203.72666
# [580]	validation_0-rmse:142.26396	validation_1-rmse:203.71361
# [581]	validation_0-rmse:142.20478	validation_1-rmse:203.70504
# [582]	validation_0-rmse:142.13450	validation_1-rmse:203.70415
# [583]	validation_0-rmse:142.10041	validation_1-rmse:203.68815
# [584]	validation_0-rmse:142.04132	validation_1-rmse:203.70532
# [585]	validation_0-rmse:141.99986	validation_1-rmse:203.65157
# [586]	validation_0-rmse:141.96188	validation_1-rmse:203.63235
# [587]	validation_0-rmse:141.92877	validation_1-rmse:203.62443
# [588]	validation_0-rmse:141.86535	validation_1-rmse:203.54015
# [589]	validation_0-rmse:141.83693	validation_1-rmse:203.52706
# [590]	validation_0-rmse:141.80161	validation_1-rmse:203.54906
# [591]	validation_0-rmse:141.74695	validation_1-rmse:203.56590
# [592]	validation_0-rmse:141.69760	validation_1-rmse:203.55666
# [593]	validation_0-rmse:141.66278	validation_1-rmse:203.56357
# [594]	validation_0-rmse:141.61357	validation_1-rmse:203.62362
# [595]	validation_0-rmse:141.54618	validation_1-rmse:203.59888
# [596]	validation_0-rmse:141.52698	validation_1-rmse:203.59860
# [597]	validation_0-rmse:141.50170	validation_1-rmse:203.60269
# [598]	validation_0-rmse:141.48638	validation_1-rmse:203.62043
# [599]	validation_0-rmse:141.42636	validation_1-rmse:203.61198
# [600]	validation_0-rmse:141.39358	validation_1-rmse:203.67162
# [601]	validation_0-rmse:141.34912	validation_1-rmse:203.66435
# [602]	validation_0-rmse:141.30566	validation_1-rmse:203.60407
# [603]	validation_0-rmse:141.20200	validation_1-rmse:203.57522
# [604]	validation_0-rmse:141.15550	validation_1-rmse:203.68151
# [605]	validation_0-rmse:141.08754	validation_1-rmse:203.66677
# [606]	validation_0-rmse:141.05392	validation_1-rmse:203.65004
# [607]	validation_0-rmse:141.00799	validation_1-rmse:203.66601
# [608]	validation_0-rmse:140.96331	validation_1-rmse:203.61595
# [609]	validation_0-rmse:140.91061	validation_1-rmse:203.59680
# [610]	validation_0-rmse:140.89137	validation_1-rmse:203.59222
# [611]	validation_0-rmse:140.85972	validation_1-rmse:203.62315
# [612]	validation_0-rmse:140.83116	validation_1-rmse:203.66401
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
from sklearn.metrics import mean_squared_log_error
rmsle = mean_squared_log_error(y_val, np.clip(y_pred, 0, None))
print(f"RMSLE: {rmsle:.4f}")
# Out:
# RMSLE: 0.2381

# %%
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
sns.histplot(y_train - y_fit, bins=30, kde=True)
plt.title("Training Residuals")
plt.xlabel("Error (Actual - Predicted)")


plt.subplot(1, 3, 2)
sns.histplot(y_val - y_pred, bins=30, kde=True, color='orange')
plt.title("Test Residuals")
plt.xlabel("Error (Actual - Predicted)")


plt.subplot(1, 3, 3)
plt.scatter(y_val, y_pred, alpha=0.1)
plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'r--')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.tight_layout()
plt.show()

# %%
plot_df = val_df.copy()
plot_df["predicted"] = y_pred
plot_df["actual"] = y_val

# Group by date and sum to collapse across all store/family combos
daily = plot_df.groupby("date")[["actual", "predicted"]].sum()

# Plot
plt.figure(figsize=(14,5))
plt.plot(daily.index, daily["actual"], label="Actual", linewidth=2)
plt.plot(daily.index, daily["predicted"], label="Predicted", linestyle="--")
plt.title("Total Sales per Day (Actual vs Predicted)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
